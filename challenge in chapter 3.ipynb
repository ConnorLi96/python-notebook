# %% [markdown]
# # The conclusion for challenge in chapter 03
#
#    ## The stuck I faced are listed below
#     - 思路
#         - 最开始的思路是觉得太复杂，先把有序的排出来，再去解决random
#         - 但是方法错了，居然想到用取商的方式，天知道我怎么想的。具体代码在最后面
#         - 解决了random的问题之后，后来想到用for 循环 一步步的完成 先从打印studentlist 再到case 再到迭代 再到优化代码。
#
#     - random
#         - 其实很简单。。只是之前chapter 02里没有提到
#         - 不过要注意 不用放到for循环，我一开始想复杂了，这个函数直接放在最左边的缩进就可以执行了
#
#     - 使用for 循环
#         - 为什么一开始没想到呢？可能因为对于for，while，if等这些还是不够熟练。会晕。
#
#     - 迭代
#         - 这个是写完for循环太兴奋，没有注意具体数字，其实并不难，细心一点！
#
#
#     - index error
#         - 之前出现了index error-list index out of range
#         - 原因：我们需要index的是有十个，而index只到第9个！而我写的是 i = 0 ,range(0,10), i +=1
#         - 解决办法：i += 1 这个只能放在print的后面！或者去掉这个逻辑
#
#
#     - 优化代码，提高效率
#         - 这个理念应该贯穿学习coding的过程，怎么最简单，用最少的步骤写出来
#         - 在一开始的时候用了def，我也不知道为什么要用。
#         - 并且用了i = 0, i+=1 这样的逻辑，其实可以不用的。

# %%
import random

c = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand"
]

s = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
]




random.shuffle(s)
random.shuffle(c)
# a是它们的商数也就是每个case里有多少个学生， b是余数 也就是还有多少个学生可以剩下来。

a = len(s) // len(c) # 这个和int是一回事
b = len(s) % len(c)
i = 0
for i in range(len(c)):  # 在这里把固定的数字换成变量 即便学生和case数量变化也不会出现index error .out of range.
    group = [c[i]]
    stu = s[a*i : a*(i+1)]
    
    if b == 0: 
        print("Assigned case:{}".format(group))
        print("student list:",stu) # 这一步只是解决了当余数等于0的情况
        continue
        # 要让每一个group里面都可以分到一个多出来的学生 
       
    if i < len(c)-(len(c)-b): # 这里取得是 case的数量减去case和余数的差
        stu = s[a*i : a*(i+1)+1] # 要让它打印b遍 还需要找到一个停止的点。
        print("Assigned case:{}".format(group))
        print("student list:",stu)
        print("===========")
  
    else: 
        stu = s[a*i : a*(i+1)]  # 要找运行的次数 当最后到 len(c)-b 组的时候 使用原来的代码
         
        print("Assigned case:{}".format(group))
        print("student list:",stu)
        print("===========")
        
    
            
    i += 1
'''
总结一下：

最后的思路在于，当余数等于0，意味着直接整除打印就行了。但是，当余数不等于0的时候，首先依次打印出：前面的组（比整除情况下，多一个分配学生）。然后再后面的按照整除数量分配的组。
比如:100个学生，13组，余数是9，每组学生整除下来应该是7人。那么先打印前9组（每组8个）。然后打印后4组（每组7个）。


这里着重需要注意的有以下几点
1 变量
要使不论学生和case的数量如何变化，都能够尽量平均分配。在大多数地方都要使用变量。上午的code就有点偷懒的嫌疑。

2 索引
因为case不确定，所以打印的行数也不确定，之前print很多行肯定是不行的。也要使用变量去完成。

3 条件表达式
在遇到这种比较复杂的情况，优先使用条件表达式，真的有助于理清思路。慢慢找到感觉。

另：在找不到思路，或者比较混乱的时候，用#写下来，一点点理清楚。
'''
# Out:
# Assigned case:['case1 - build a calculator to evaluate your business model']
# student list: [18421114, 18421121, 18421116, 18421127, 18421124, 18421126, 18421125]
# ...
# Assigned case:['case2 - build a automatic earthquake robot to broadcast the new earthquake']
# student list: [18421125, 18421113, 18421128, 18421129, 18421115, 18421120, 18421112]
# ...
# Assigned case:['case3 - evaluate social media performance of a luxury brand']
# student list: [18421112, 18421117, 18421111, 18421118, 18421122, 18421123]
# ...
# '\n总结一下：\n\n最后的思路在于，当余数等于0，意味着直接整除打印就行了。但是，当余数不等于0的时候，首先依次打印出：前面的组（比整除情况下，多一个分配学生）。然后再后面的按照整除数量分配的组。\n比如:100个学生，13组，余数是9，每组学生整除下来应该是7人。那么先打印前9组（每组8个）。然后打印后4组（每组7个）。\n\n\n这里着重需要注意的有以下几点\n1 变量\n要使不论学生和case的数量如何变化，都能够尽量平均分配。在大多数地方都要使用变量。上午的code就有点偷懒的嫌疑。\n\n2 索引\n因为case不确定，所以打印的行数也不确定，之前print很多行肯定是不行的。也要使用变量去完成。\n\n3 条件表达式\n在遇到这种比较复杂的情况，优先使用条件表达式，真的有助于理清思路。慢慢找到感觉。\n\n另：在找不到思路，或者比较混乱的时候，用#写下来，一点点理清楚。\n'

# %%
# further challenge

import random
stu = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
]
case = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand"]

random.shuffle(stu)
random.shuffle(case)





d = int(len(stu)/len(case))
e = len(stu)%len(case)
print(e)
for i in range(len(case)):
    print('group {}'.format(i+1))
    print('student_list: {}'.format(stu[i*d]))
    print('student_list: {}'.format(stu[i*d+1]))
    print('student_list: {}'.format(stu[i*d+2]))
    if i == len(case) -1:
        print('student_list: {}'.format(stu[-1]))
    print("case assinged in :{}".format(case[i]))   



    
# The main stuck situation I faced is how to add the last student number to one group rather than every group.
# The following is my orignal code.
'''
e = a%b

if e != 0:
        print(stu[i*d+3])
        
'''
        
# It can work to find the last number but every group will have 4 student numbers. 
# However, the last number can be indexed by -1, 
# and I don't need to add it to one group, just utilize the for loop. when it operate to last case, print last student number.

'''
Conclusion

I suppose the the reason of stuck is connected with unskilled programming and thinking strategy, I always use complex ways to solve problems.
But the process of dealing with problems greatly help me to understand python with a bit of sense of achievement.
'''
# Out:
# 1
# group 1
# student_list: 18421120
# student_list: 18421119
# student_list: 18421116
# case assinged in :case2 - build a automatic earthquake robot to broadcast the new earthquake
# group 2
# student_list: 18421113
# student_list: 18421111
# student_list: 18421115
# case assinged in :case3 - evaluate social media performance of a luxury brand
# group 3
# student_list: 18421112
# student_list: 18421118
# student_list: 18421117
# student_list: 18421114
# case assinged in :case1 - build a calculator to evaluate your business model
# '\nConclusion\n\nI suppose the the reason of stuck is connected with unskilled programming and thinking strategy, I always use complex ways to solve problems.\nBut the process of dealing with problems greatly help me to understand python with a bit of sense of achievement.\n'

# %%
# try to use the random
import random
print(random.randrange(1,11))

# %%
# 解决了怎么用shuffling  

case_list = ["case1", "case2","case3","case4","case5","case6","case7","case8","case9","case10"]
from random import shuffle

x = [[i] for i in case_list]
shuffle(x)
print(x)
# Out:
# [['case9'], ['case4'], ['case7'], ['case6'], ['case2'], ['case3'], ['case5'], ['case1'], ['case10'], ['case8']]

# %%
import random

case_list = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand",
"case4 - study movie blockbuster 'Dying to Survive'",
 "case5 - invest your money like the Internet giant, Tencent",
"case6 - where are the 200,000 inferior vaccines flowing?",
"case7 - study classics, who control the discourse power in 'Dream of the Red Chamber'?",
"case8 - research about Didi-driver crimes in China",
"case9 - 'Me too' analysis",
"case10 - What is hip-hop in china?"]

student_list = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
18421131,
18421132,
18421133,
18421134,
18421135,
18421136,
18421137,
18421138,
18421139,
18421140,
18421141,
18421142,
18421143,
18421144,
18421145,
18421146,
18421147,
18421148,
18421149,
18421150,
18421151,
18421152,
18421153,
18421154,
18421155,
18421156,
18421157,
18421158,
18421159,
18421160]


#比较有效率的代码应该实现：每出现一个group 就会从case里调一个出来，并从student里面调5个出来

random.shuffle(student_list )
random.shuffle(case_list)
# 注：不要把random函数放到for循环里，不管用，扔出去，它会执行的。




for i in range(0,10):  
    print("group{}".format(i+1))
    print("student ID:{}".format(student_list [i*5]))   # 这里之前迭代出现了问题
    print("student ID:{}".format(student_list [i*5+1]) )
    print("student ID:{}".format(student_list [i*5+2]) )
    print("student ID:{}".format(student_list [i*5+3]) )
    print("student ID:{}".format(student_list [i*5+4]) )
    print("Assigned case:{}".format(case_list[i]))# 蠢了一下。 不要用固定的数字index  直接把i 丢进去就行了
    print("===============")

# 其实i+= 1 和i= 0 在这个代码里是可以不用的。
# Out:
# group1
# student ID:18421122
# student ID:18421116
# student ID:18421131
# student ID:18421146
# student ID:18421125
# Assigned case:case7 - study classics, who control the discourse power in 'Dream of the Red Chamber'?
# ...
# group2
# student ID:18421157
# student ID:18421158
# student ID:18421117
# student ID:18421135
# student ID:18421112
# Assigned case:case5 - invest your money like the Internet giant, Tencent
# ...
# group3
# student ID:18421137
# student ID:18421127
# student ID:18421154
# student ID:18421134
# student ID:18421147
# Assigned case:case10 - What is hip-hop in china?
# ...
# group4
# student ID:18421136
# student ID:18421113
# student ID:18421130
# student ID:18421141
# student ID:18421128
# Assigned case:case4 - study movie blockbuster 'Dying to Survive'
# ...
# group5
# student ID:18421156
# student ID:18421151
# student ID:18421133
# student ID:18421115
# student ID:18421148
# Assigned case:case8 - research about Didi-driver crimes in China
# ...
# group6
# student ID:18421129
# ...

# %%
student_list = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
18421131,
18421132,
18421133,
18421134,
18421135,
18421136,
18421137,
18421138,
18421139,
18421140,
18421141,
18421142,
18421143,
18421144,
18421145,
18421146,
18421147,
18421148,
18421149,
18421150,
18421151,
18421152,
18421153,
18421154,
18421155,
18421156,
18421157,
18421158,
18421159,
18421160]
case_list = ["case1", "case2","case3","case4","case5","case6","case7","case8","case9","case10"]


'''
 大致思路：
 
    1 首先解决如何生成group1～10  group 应该从学生列表里面来 
        1.1 试一下当碰到5的倍数就continue 然后生成group 
            1.1.1 可以把列表每5个打印出来，但是为什么停不下。。。。
        1.2 每当5个从里面移出来以后，再用remove 从list里面踢掉。。。真的有这么复杂嘛
        
        
    2 解决group和case之间的联系 如何一一对应 具体打印group应该可以和case放在一起
    
    
    3 先试着按照顺序打印，最后看能不能解决random的问题
        3.1 在学长提示以后，找到了怎么做random
    
'''
    


for i in student_list:
    
    i = 18421110
    while i < 18421160:
        
        i += 1
        if i%5 == 0:
            print("Student ID: {}".format (i))
            print("Student ID: {}".format (i-1))
            print("Student ID: {}".format (i-2))
            print("Student ID: {}".format (i-3))
            print("Student ID: {}".format (i-4))
        
        if i == 18421160
            break
# 思路错了 换一个  这个留着当反面教材

# %%
# Out:
# group 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-278bc776d95f> in <module>()
#      71     stu = student_list[i*5 : 5*(i+1)]
#      72     print("group {}".format(i))
# ---> 73     print("student ID:" (stu))
#
# TypeError: 'str' object is not callable

# %%
import random
stu = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,]
case = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand","case4"]

random.shuffle(stu)
random.shuffle(case)

i = 0
while (i<3):
    group = [case[i]]
    stu = stu[3*i : 3*(i+1)]
    print("group case:",group)
    print("student list:",stu)
    i += 1
# Out:
# group case: ['case3 - evaluate social media performance of a luxury brand']
# student list: [18421117, 18421111, 18421118]
# group case: ['case2 - build a automatic earthquake robot to broadcast the new earthquake']
# student list: []
# group case: ['case4']
# student list: []

# %%
import random

c = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand",
]

s = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
]




random.shuffle(s)
random.shuffle(c)
# a是它们的商数也就是每个case里有多少个学生， b是余数 也就是还有多少个学生可以剩下来。

a = len(s) // len(c) # 这个和int是一回事
b = len(s) % len(c)
i = 0
while (i < len(c)):  # 在这里把固定的数字换成变量 即便学生和case数量变化也不会出现index error .out of range.
    group = [c[i]]
    stu = s[a*i : a*(i+1)]
    
    if i == len(c)-1: # 这个if的条件表达式仅仅只能针对最后一个生成的group
        stu = s[a*i : a*(i+1)+b] # 要让每一个group里面都可以分到一个多出来的学生
        print("group case:",group)
        print("student list:",stu)
        
    else:
        print("group case:",group)
        print("student list:",stu) # else 这一步仅仅只是解决了当余数等于0的情况。





    i += 1
print(b)
# Out:
# group case: ['case1 - build a calculator to evaluate your business model']
# student list: [18421112, 18421121, 18421115]
# group case: ['case2 - build a automatic earthquake robot to broadcast the new earthquake']
# student list: [18421118, 18421111, 18421117]
# group case: ['case3 - evaluate social media performance of a luxury brand']
# student list: [18421119, 18421116, 18421120, 18421113, 18421114]
# 2

# %%
import random

c = ["case1 - build a calculator to evaluate your business model",
"case2 - build a automatic earthquake robot to broadcast the new earthquake",
"case3 - evaluate social media performance of a luxury brand","case4","case5","case6","case7"
]

s = [
18421111,
18421112,
18421113,
18421114,
18421115,
18421116,
18421117,
18421118,
18421119,
18421120,
18421121,
18421122,
18421123,
18421124,
18421125,
18421126,
18421127,
18421128,
18421129,
18421130,
]




random.shuffle(s)
random.shuffle(c)
# a是它们的商数也就是每个case里有多少个学生， b是余数 也就是还有多少个学生可以剩下来。

a = len(s) // len(c) # 这个和int是一回事
b = len(s) % len(c)
i = 0
for i in range(len(c)):  # 在这里把固定的数字换成变量 即便学生和case数量变化也不会出现index error .out of range.
    group = [c[i]]
    stu = s[a*i : a*(i+1)]
    
    if b == 0: 
        print("Assigned case:{}".format(group))
        print("student list:",stu) # 这一步只是解决了当余数等于0的情况
        continue
        # 要让每一个group里面都可以分到一个多出来的学生 
       
    if i < len(c)-(len(c)-b): # 这里取得是 case的数量减去case和余数的差
        stu = s[a*i : a*(i+1)+1] # 要让它打印b遍 还需要找到一个停止的点。
        print("Assigned case:{}".format(group))
        print("student list:",stu)
        print("===========")
  
    else: 
        stu = s[a*i : a*(i+1)]  # 要找运行的次数 当最后到 len(c)-b 组的时候 使用原来的代码
         
        print("Assigned case:{}".format(group))
        print("student list:",stu)
        print("===========")
        
        
            
    i += 1
# Out:
# Assigned case:['case6']
# student list: [18421114, 18421124, 18421129]
# ...
# Assigned case:['case5']
# student list: [18421129, 18421128, 18421121]
# ...
# Assigned case:['case4']
# student list: [18421121, 18421112, 18421111]
# ...
# Assigned case:['case2 - build a automatic earthquake robot to broadcast the new earthquake']
# student list: [18421111, 18421116, 18421120]
# ...
# Assigned case:['case3 - evaluate social media performance of a luxury brand']
# student list: [18421120, 18421126, 18421123]
# ...
# Assigned case:['case1 - build a calculator to evaluate your business model']
# student list: [18421123, 18421117, 18421125]
# ...
# Assigned case:['case7']
# student list: [18421125, 18421122]
# ...
